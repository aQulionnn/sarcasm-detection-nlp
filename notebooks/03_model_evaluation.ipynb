# %%
eval_results = model.evaluate(X_test, y_test)
# Out:
# 110/110 [==============================] - 34s 310ms/step - loss: 0.2576 - accuracy: 0.8994 - precision: 0.9145 - recall: 0.8812

# %%
import numpy as np

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.flatten()
y_pred = np.where(y_pred > 0.5, 1, 0)
# Out:
# 110/110 [==============================] - 34s 299ms/step

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      1759
#            1       0.91      0.88      0.90      1759
#
#     accuracy                           0.90      3518
#    macro avg       0.90      0.90      0.90      3518
# weighted avg       0.90      0.90      0.90      3518

# %%
from datetime import datetime

# %%
accuracy = eval_results[model.metrics_names.index('accuracy')]
date = datetime.now().strftime("%d%m%Y")

model_name = f"smallbert_L10H128A2_{date}_epoch5_accuracy{accuracy:.2f}.keras"
print(model_name)
# Out:
# smallbert_L10H128A2_29122025_epoch5_accuracy0.90.keras

# %%
model.save(f"../models/{model_name}")
