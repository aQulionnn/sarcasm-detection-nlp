# %%
eval_results = model.evaluate(X_test, y_test)
# Out:
# 184/184 [==============================] - 59s 317ms/step - loss: 0.6445 - accuracy: 0.6402 - precision: 0.6632 - recall: 0.5698

# %%
import numpy as np

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.flatten()
y_pred = np.where(y_pred > 0.5, 1, 0)
# Out:
# 184/184 [==============================] - 57s 305ms/step

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.66      2931
#            1       0.66      0.57      0.61      2931
#
#     accuracy                           0.64      5862
#    macro avg       0.64      0.64      0.64      5862
# weighted avg       0.64      0.64      0.64      5862
