# %%
eval_results = model.evaluate(X_test_padded, y_test)
# Out:
# 110/110 [==============================] - 4s 18ms/step - loss: 0.3986 - accuracy: 0.8283 - precision: 0.9064 - recall: 0.7322

# %%
import numpy as np

# %%
y_pred = model.predict(X_test_padded)
y_pred = y_pred.flatten()
y_pred = np.where(y_pred > 0.5, 1, 0)
# Out:
# 110/110 [==============================] - 3s 17ms/step

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.84      1759
#            1       0.91      0.73      0.81      1759
#
#     accuracy                           0.83      3518
#    macro avg       0.84      0.83      0.83      3518
# weighted avg       0.84      0.83      0.83      3518

# %%
from datetime import datetime

# %%
accuracy = eval_results[model.metrics_names.index('accuracy')]
date = datetime.now().strftime("%d%m%Y")

model_name = f"lstm_{date}_epoch5_accuracy{accuracy:.2f}.keras"
print(model_name)
# Out:
# lstm_30122025_epoch5_accuracy0.83.keras

# %%
model.save(f"../models/{model_name}")
