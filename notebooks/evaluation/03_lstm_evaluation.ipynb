# %%
eval_results = model.evaluate(X_test_padded, y_test)
# Out:
# 141/141 [==============================] - 3s 13ms/step - loss: 0.2735 - accuracy: 0.8941 - precision: 0.9005 - recall: 0.8861

# %%
import numpy as np

# %%
y_pred = model.predict(X_test_padded)
y_pred = y_pred.flatten()
y_pred = np.where(y_pred > 0.5, 1, 0)
# Out:
# 141/141 [==============================] - 2s 7ms/step

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89      2248
#            1       0.90      0.89      0.89      2248
#
#     accuracy                           0.89      4496
#    macro avg       0.89      0.89      0.89      4496
# weighted avg       0.89      0.89      0.89      4496

# %%
from datetime import datetime

# %%
accuracy = eval_results[model.metrics_names.index('accuracy')]
date = datetime.now().strftime("%d%m%Y")

model_name = f"oversampled_lstm_{date}_epoch7_accuracy{accuracy:.2f}.keras"
print(model_name)
# Out:
# oversampled_lstm_03012026_epoch7_accuracy0.89.keras

# %%
model.save(f"../../models/{model_name}")
