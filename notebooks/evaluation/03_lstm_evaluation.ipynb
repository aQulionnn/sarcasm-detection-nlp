# %%
eval_results = model.evaluate(X_test_padded, y_test)
# Out:
# 141/141 [==============================] - 3s 11ms/step - loss: 0.3198 - accuracy: 0.8701 - precision: 0.8665 - recall: 0.8750

# %%
import numpy as np

# %%
y_pred = model.predict(X_test_padded)
y_pred = y_pred.flatten()
y_pred = np.where(y_pred > 0.5, 1, 0)
# Out:
# 141/141 [==============================] - 2s 5ms/step

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      2248
#            1       0.87      0.88      0.87      2248
#
#     accuracy                           0.87      4496
#    macro avg       0.87      0.87      0.87      4496
# weighted avg       0.87      0.87      0.87      4496

# %%
from datetime import datetime

# %%
accuracy = eval_results[model.metrics_names.index('accuracy')]
date = datetime.now().strftime("%d%m%Y")

model_name = f"lstm_{date}_epoch3_accuracy{accuracy:.2f}.keras"
print(model_name)
# Out:
# lstm_31122025_epoch3_accuracy0.84.keras

# %%
model.save(f"../models/{model_name}")
