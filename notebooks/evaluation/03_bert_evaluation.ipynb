# %%
eval_results = model.evaluate(X_test, y_test)
# Out:
# 141/141 [==============================] - 25s 174ms/step - loss: 0.2156 - accuracy: 0.9208 - precision: 0.9099 - recall: 0.9342

# %%
import numpy as np

# %%
y_pred = model.predict(X_test)
y_pred = y_pred.flatten()
y_pred = np.where(y_pred > 0.5, 1, 0)
# Out:
# 141/141 [==============================] - 27s 188ms/step

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      2248
#            1       0.91      0.93      0.92      2248
#
#     accuracy                           0.92      4496
#    macro avg       0.92      0.92      0.92      4496
# weighted avg       0.92      0.92      0.92      4496

# %%
from datetime import datetime

# %%
accuracy = eval_results[model.metrics_names.index('accuracy')]
date = datetime.now().strftime("%d%m%Y")

model_name = f"oversampled_smallbert_L10H128A2_{date}_epoch10_accuracy{accuracy:.2f}.keras"
print(model_name)
# Out:
# oversampled_smallbert_L10H128A2_05012026_epoch10_accuracy0.92.keras

# %%
model.save(f"../../models/{model_name}")
