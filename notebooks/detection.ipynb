# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentences = [
    'I love coding',
    'I hate coding',
    'I enjoy learning new technologies',
    'I dislike debugging late at night'
]

tokenizer = Tokenizer(num_words=100, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index

sequences = tokenizer.texts_to_sequences(sentences)

print(word_index)
print(sequences)
# Out:
# {'<OOV>': 1, 'i': 2, 'coding': 3, 'love': 4, 'hate': 5, 'enjoy': 6, 'learning': 7, 'new': 8, 'technologies': 9, 'dislike': 10, 'debugging': 11, 'late': 12, 'at': 13, 'night': 14}
# [[2, 4, 3], [2, 5, 3], [2, 6, 7, 8, 9], [2, 10, 11, 12, 13, 14]]

# %%
test_data = [
    'I admire creative ideas',
    'I avoid complex problems'
]

test_sequences = tokenizer.texts_to_sequences(test_data)

print(test_sequences)
# Out:
# [[2, 1, 1, 1], [2, 1, 1, 1]]

# %%
padded_sequences = pad_sequences(sequences, padding='post', truncating='post', maxlen=3)

print(padded_sequences)
# Out:
# [[ 2  4  3]
#  [ 2  5  3]
#  [ 2  6  7]
#  [ 2 10 11]]

# %%
import pandas as pd

# %%
sarcasm_headlines = pd.read_json("../data/sarcasm-headlines.json", lines=True)

sentences = sarcasm_headlines['headline'].tolist()
labels = sarcasm_headlines['is_sarcastic'].tolist()
urls = sarcasm_headlines['article_link'].tolist()

# %%
from sklearn.model_selection import train_test_split

# %%
training_sentences, testing_sentences, training_labels, testing_labels = train_test_split(
    sentences,
    labels,
    test_size=0.25,
    random_state=42
)

# %%
tokenizer = Tokenizer(num_words=100, oov_token="<OOV>")
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, padding='post', truncating='post', maxlen=40)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, padding='post', truncating='post', maxlen=40)

# %%
from tensorflow.keras import layers

# %%
embedding_dim = 32

model = keras.Sequential([
    layers.Embedding(100, embedding_dim),
    layers.GlobalAveragePooling1D(),
    layers.Dense(24, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
training_padded = tf.constant(training_padded)
testing_padded = tf.constant(testing_padded)
training_labels = tf.constant(training_labels)
testing_labels = tf.constant(testing_labels)

# %%
history = model.fit(training_padded, training_labels, epochs=30, validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# Epoch 1/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7638 - loss: 0.4693 - val_accuracy: 0.7492 - val_loss: 0.4866
# Epoch 2/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7633 - loss: 0.4686 - val_accuracy: 0.7525 - val_loss: 0.4897
# Epoch 3/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7647 - loss: 0.4686 - val_accuracy: 0.7574 - val_loss: 0.4827
# Epoch 4/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7656 - loss: 0.4682 - val_accuracy: 0.7591 - val_loss: 0.4795
# Epoch 5/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7661 - loss: 0.4683 - val_accuracy: 0.7529 - val_loss: 0.4844
# Epoch 6/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7664 - loss: 0.4680 - val_accuracy: 0.7552 - val_loss: 0.4812
# Epoch 7/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7651 - loss: 0.4685 - val_accuracy: 0.7564 - val_loss: 0.4798
# Epoch 8/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7666 - loss: 0.4671 - val_accuracy: 0.7558 - val_loss: 0.4831
# Epoch 9/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7641 - loss: 0.4702 - val_accuracy: 0.7567 - val_loss: 0.4799
# Epoch 10/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7635 - loss: 0.4697 - val_accuracy: 0.7543 - val_loss: 0.4880
# Epoch 11/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7652 - loss: 0.4662 - val_accuracy: 0.7546 - val_loss: 0.4851
# Epoch 12/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7610 - loss: 0.4679 - val_accuracy: 0.7552 - val_loss: 0.4844
# Epoch 13/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7674 - loss: 0.4674 - val_accuracy: 0.7306 - val_loss: 0.5355
# Epoch 14/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7627 - loss: 0.4667 - val_accuracy: 0.7523 - val_loss: 0.4864
# Epoch 15/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7655 - loss: 0.4666 - val_accuracy: 0.7582 - val_loss: 0.4815
# Epoch 16/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7683 - loss: 0.4655 - val_accuracy: 0.7538 - val_loss: 0.4860
# Epoch 17/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7686 - loss: 0.4651 - val_accuracy: 0.7577 - val_loss: 0.4791
# Epoch 18/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7675 - loss: 0.4653 - val_accuracy: 0.7526 - val_loss: 0.4838
# Epoch 19/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7686 - loss: 0.4645 - val_accuracy: 0.7604 - val_loss: 0.4784
# Epoch 20/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7661 - loss: 0.4632 - val_accuracy: 0.7487 - val_loss: 0.4837
# Epoch 21/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7684 - loss: 0.4642 - val_accuracy: 0.7609 - val_loss: 0.4783
# Epoch 22/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7684 - loss: 0.4636 - val_accuracy: 0.7592 - val_loss: 0.4786
# Epoch 23/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7671 - loss: 0.4641 - val_accuracy: 0.7582 - val_loss: 0.4780
# Epoch 24/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7684 - loss: 0.4613 - val_accuracy: 0.7570 - val_loss: 0.4804
# Epoch 25/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7703 - loss: 0.4618 - val_accuracy: 0.7595 - val_loss: 0.4750
# Epoch 26/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7694 - loss: 0.4608 - val_accuracy: 0.7588 - val_loss: 0.4751
# Epoch 27/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7686 - loss: 0.4618 - val_accuracy: 0.7609 - val_loss: 0.4768
# Epoch 28/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7698 - loss: 0.4614 - val_accuracy: 0.7583 - val_loss: 0.4757
# Epoch 29/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7703 - loss: 0.4604 - val_accuracy: 0.7559 - val_loss: 0.4809
# Epoch 30/30
# 626/626 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7697 - loss: 0.4595 - val_accuracy: 0.7397 - val_loss: 0.4896

# %%
sentence = [
    "Oh great, another Monday—just what I needed!",
    "I’m excited to start my new project today."
]

sequences = tokenizer.texts_to_sequences(sentence)

padded = pad_sequences(sequences, padding='post', truncating='post', maxlen=40)

print(model.predict(padded))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# [[0.06529946]
#  [0.11236033]]
